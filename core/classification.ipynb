# %% [markdown]
# # Classification

# %% [markdown]
# Differentiating 3 flower types based on their features

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
train_path = tf.keras.utils.get_file("iris_trainig.csv","https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file("iris_test.csv","https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength','PetalWidth','Species']
SPECIES = ['Setosa','Versicolor', 'Virginica']

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)
train_y = train.pop('Species')
test_y = test.pop('Species')

train_y = pd.get_dummies(train_y, columns=['Species'], drop_first=False)
test_y = pd.get_dummies(test_y, columns=['Species'], drop_first=False)


train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
train_y.head()
# Out:
# 0    2
# 1    1
# 2    2
# 3    0
# 4    0
# Name: Species, dtype: int64

# %% [markdown]
# # Explore

# %%
print('train:',train.shape,
      'test:', test.shape)
# Out:
# train: (120, 4) test: (30, 4)

# %% [markdown]
# # training

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation=tf.nn.relu, input_shape=(4,)),  # input shape required
  tf.keras.layers.Dense(10, activation=tf.nn.relu),
  tf.keras.layers.Dense(3, activation='softmax', name='output')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# Epoch 1/200
# /home/aap9002/Documents/Projects/FCC-TensorFlow-Training/FCC-TF/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 24/24 - 1s - 29ms/step - accuracy: 0.3000 - loss: 1.2303
# Epoch 2/200
# 24/24 - 0s - 1ms/step - accuracy: 0.3000 - loss: 1.1208
# Epoch 3/200
# 24/24 - 0s - 1ms/step - accuracy: 0.3000 - loss: 1.0508
# Epoch 4/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7250 - loss: 1.0036
# Epoch 5/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.9693
# Epoch 6/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.9383
# Epoch 7/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.9044
# Epoch 8/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.8736
# Epoch 9/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.8433
# Epoch 10/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.8119
# Epoch 11/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.7787
# Epoch 12/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.7473
# Epoch 13/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.7158
# Epoch 14/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.6862
# Epoch 15/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7083 - loss: 0.6548
# Epoch 16/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7000 - loss: 0.6297
# Epoch 17/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7083 - loss: 0.6008
# Epoch 18/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7167 - loss: 0.5768
# Epoch 19/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7167 - loss: 0.5561
# Epoch 20/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7417 - loss: 0.5354
# Epoch 21/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7417 - loss: 0.5180
# Epoch 22/200
# 24/24 - 0s - 1ms/step - accuracy: 0.8250 - loss: 0.5026
# Epoch 23/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7750 - loss: 0.4858
# Epoch 24/200
# 24/24 - 0s - 1ms/step - accuracy: 0.7917 - loss: 0.4713
# Epoch 25/200
# 24/24 - 0s - 1ms/step - accuracy: 0.8083 - loss: 0.4586
# Epoch 26/200
# 24/24 - 0s - 1ms/step - accuracy: 0.8583 - loss: 0.4454
# Epoch 27/200
# 24/24 - 0s - 2ms/step - accuracy: 0.8500 - loss: 0.4330
# Epoch 28/200
# 24/24 - 0s - 2ms/step - accuracy: 0.8833 - loss: 0.4205
# Epoch 29/200
# 24/24 - 0s - 1ms/step - accuracy: 0.8167 - loss: 0.4172
# Epoch 30/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9083 - loss: 0.4041
# Epoch 31/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9250 - loss: 0.3896
# Epoch 32/200
# 24/24 - 0s - 1ms/step - accuracy: 0.8917 - loss: 0.3821
# Epoch 33/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9000 - loss: 0.3723
# Epoch 34/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9333 - loss: 0.3644
# Epoch 35/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9500 - loss: 0.3523
# Epoch 36/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9250 - loss: 0.3412
# Epoch 37/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.3323
# Epoch 38/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9417 - loss: 0.3204
# Epoch 39/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.3118
# Epoch 40/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.3006
# Epoch 41/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9583 - loss: 0.2918
# Epoch 42/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9417 - loss: 0.2886
# Epoch 43/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2771
# Epoch 44/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2650
# Epoch 45/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2599
# Epoch 46/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2519
# Epoch 47/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2452
# Epoch 48/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2391
# Epoch 49/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2335
# Epoch 50/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2274
# Epoch 51/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2281
# Epoch 52/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2158
# Epoch 53/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2170
# Epoch 54/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9667 - loss: 0.2051
# Epoch 55/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9667 - loss: 0.2014
# Epoch 56/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9667 - loss: 0.1951
# Epoch 57/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1915
# Epoch 58/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1866
# Epoch 59/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1824
# Epoch 60/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1782
# Epoch 61/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1759
# Epoch 62/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1728
# Epoch 63/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1681
# Epoch 64/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.1671
# Epoch 65/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1607
# Epoch 66/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1565
# Epoch 67/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1567
# Epoch 68/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1516
# Epoch 69/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1510
# Epoch 70/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1474
# Epoch 71/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1487
# Epoch 72/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1427
# Epoch 73/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1406
# Epoch 74/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1430
# Epoch 75/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1374
# Epoch 76/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1335
# Epoch 77/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1300
# Epoch 78/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1291
# Epoch 79/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1285
# Epoch 80/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1259
# Epoch 81/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1225
# Epoch 82/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1209
# Epoch 83/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1199
# Epoch 84/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1175
# Epoch 85/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1185
# Epoch 86/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1144
# Epoch 87/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1139
# Epoch 88/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1165
# Epoch 89/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1137
# Epoch 90/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1209
# Epoch 91/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1143
# Epoch 92/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1105
# Epoch 93/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1052
# Epoch 94/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1053
# Epoch 95/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1068
# Epoch 96/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1045
# Epoch 97/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0998
# Epoch 98/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1007
# Epoch 99/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0999
# Epoch 100/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1023
# Epoch 101/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1030
# Epoch 102/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1004
# Epoch 103/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0958
# Epoch 104/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0945
# Epoch 105/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0964
# Epoch 106/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0931
# Epoch 107/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0949
# Epoch 108/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0931
# Epoch 109/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0941
# Epoch 110/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0911
# Epoch 111/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0908
# Epoch 112/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0908
# Epoch 113/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0924
# Epoch 114/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0892
# Epoch 115/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0863
# Epoch 116/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0912
# Epoch 117/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0896
# Epoch 118/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0894
# Epoch 119/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.0894
# Epoch 120/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0882
# Epoch 121/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0860
# Epoch 122/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0834
# Epoch 123/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0828
# Epoch 124/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0839
# Epoch 125/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0844
# Epoch 126/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0825
# Epoch 127/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0895
# Epoch 128/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0844
# Epoch 129/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0815
# Epoch 130/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0813
# Epoch 131/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0805
# Epoch 132/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0804
# Epoch 133/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0777
# Epoch 134/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.0781
# Epoch 135/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0785
# Epoch 136/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0775
# Epoch 137/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0795
# Epoch 138/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0776
# Epoch 139/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0759
# Epoch 140/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0759
# Epoch 141/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0857
# Epoch 142/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0738
# Epoch 143/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0802
# Epoch 144/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0763
# Epoch 145/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0749
# Epoch 146/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0781
# Epoch 147/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0783
# Epoch 148/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0792
# Epoch 149/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0812
# Epoch 150/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0742
# Epoch 151/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0747
# Epoch 152/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.0741
# Epoch 153/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0765
# Epoch 154/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0749
# Epoch 155/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0806
# Epoch 156/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.0754
# Epoch 157/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.0737
# Epoch 158/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0782
# Epoch 159/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0722
# Epoch 160/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.0727
# Epoch 161/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.0703
# Epoch 162/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.0725
# Epoch 163/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0775
# Epoch 164/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0725
# Epoch 165/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0716
# Epoch 166/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0699
# Epoch 167/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0718
# Epoch 168/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0702
# Epoch 169/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0711
# Epoch 170/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0677
# Epoch 171/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0723
# Epoch 172/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0683
# Epoch 173/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0679
# Epoch 174/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0689
# Epoch 175/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.0762
# Epoch 176/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0690
# Epoch 177/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0690
# Epoch 178/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0720
# Epoch 179/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0707
# Epoch 180/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0703
# Epoch 181/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0697
# Epoch 182/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0682
# Epoch 183/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0674
# Epoch 184/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0714
# Epoch 185/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0787
# Epoch 186/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0703
# Epoch 187/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.0661
# Epoch 188/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0661
# Epoch 189/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0655
# Epoch 190/200
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.0656
# Epoch 191/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0676
# Epoch 192/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0708
# Epoch 193/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0682
# Epoch 194/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0657
# Epoch 195/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0719
# Epoch 196/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.0669
# Epoch 197/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0627
# Epoch 198/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.0721
# Epoch 199/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0728
# Epoch 200/200
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.0632

# %%
results = model.evaluate(test, test_y)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9667 - loss: 0.0638

# %%
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Final test set loss: 0.063820
# Final test set accuracy: 0.966667

# %%
predictions = pd.DataFrame(model.predict(test))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
print(np.argmax(predictions, axis=1)[:5])
test_y.head()
# Out:
# [1 2 0 1 1]
#        0      1      2
# 0  False   True  False
# 1  False  False   True
# 2   True  False  False
# 3  False   True  False
# 4  False   True  False
